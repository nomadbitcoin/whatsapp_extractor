# %%
import time
import os
from datetime import datetime, date, timedelta
import pandas as pd
# pd.set_option('display.max_rows', 1000)

# %%
from engines import saveData

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options as ChromeOptions
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

#instance headless
options = webdriver.ChromeOptions()
#options.add_argument('headless')
#options.add_argument('--window-size-1920x1080')

# open with saved informations in cache
options.add_argument("profile")
options.add_argument("user-data-dir=./whatsapp_nabike")
# options.add_argument("user-data-dir=./whatsapp_yan")

driver = webdriver.Chrome(options=options, executable_path="./webdriver/chromedriver")
driver.get('https://web.whatsapp.com/')

# %%
# FUNCOES QUE PEGAM AS INFORMACOES DO CONTATO
def getImage():
    # PEGA IMAGEM
    try:
        contact_info['image'] = div_right.find_element_by_xpath('//div[@class="_2vJOg"]').find_element_by_css_selector('img').get_property('src')  
        return True
    except Exception as error:
        pass
        #print('getImage() error: {}'.format(error))

def getCaption():
    # PEGA LEGENDA
    try:
        contact_info['caption'] = div_right.find_element_by_xpath('//span[@class="_19RFN"]').text
        return True
    except Exception as error:
        pass
        #print('getCaption() error: {}'.format(error))

def getPhone():
    # PEGA O TELEFONE E SE EH CONTA COMERCIAL
    elements = div_right.find_elements_by_xpath('//span[@class="_6xQdq"]')
    for fone in elements:
        #verifica se eh conta comercial
        if fone.text == 'Conta comercial':
            contact_info['business'] = True
        #salva o numero
        if fone.text.startswith('+'):
            contact_info['phone'] = fone.text
            
def get_Name():
    # RETORNA TRUE SE O CONTATO ESTIVER SALVO E FALSE CASO CONTRARIO, SE NAO ESTIVER VERIFICA SE O USUARIO DEIXOU O NOME PUBLICO
    try:
        c_name = div_right.find_element_by_xpath('//span[@class="_1drsQ"]').text
        if c_name.startswith('+'):
            #verifica se o nome esta publico entao salva o nome e false porque nao esta salvo
            try:
                #salva o nome de contato
                c_name = div_right.find_element_by_xpath('//span[@class="_1qWhd"]').text
                contact_info['saved'] = False
                contact_info['name'] = c_name
            except Exception as error:
                print('getImageName() [step 1] error: {}'.format(error))
        else:
            #se nao comecar com + eh porque o contato esta salvo
            contact_info['saved'] = True
            
            c_name = driver.find_element_by_class_name('_1drsQ').text
            contact_info['name'] = c_name
            
            #POR ALGUMA RAZAO ELE NAO PEGA O NOME DE PRIMEIRA ALGUMAS VEZES
            if c_name == '':
                for i in range(10):
                    c_name = driver.find_element_by_class_name('_1drsQ').text
                    contact_info['name'] = c_name
                    if c_name != '':
                        break
            ################################################################
    except Exception as error:
        pass
        #print('getName() [step 2] error: {}'.format(error))

# %%
# FUNCOES DE NAVEGACAO PELO WHATSAPP COM CLIQUES E TECLAS DO TECLADO
def down_chat(force=False):
    #force = True ira clicar na caixa de pesquisa e reiniciar o processo de clicar nos botoes
    if 'press_down' not in globals() or force == True:
        # CLICA NA CAIXA DE PESQUISA DE CONVERSAS
        driver.find_element_by_class_name('_2zCfw').click()
        
        # PRESSIONA A TECLA DOWN PARA NAVEGAR ENTRE AS CONVERSAS
        global press_down
        press_down = ActionChains(driver)
        press_down.send_keys(Keys.DOWN)
        press_down.perform()
    else:
        press_down.perform()

def click_on_contact():
    try:
        c_info = div_right.find_element_by_xpath('//header[@class="_3fs0K"]')
        time.sleep(0.5)
        c_info.click()
        time.sleep(0.5)
        return True
    except:
        return False
        
def esc_conversation():
    press_esc = ActionChains(driver)
    press_esc.send_keys(Keys.ESCAPE)
    press_esc.perform()

# %%
# PEGA AS INFORMACOES DO CONTATO COM O QUAL TEVE A CONVERSA
def getContactData():
    # INFORMACOES DA CONVERSA E DO USUARIO
    global div_right
    div_right = driver.find_element_by_class_name('_3HZor')

    global contact_info
    contact_info = {'business': False, 'image': None, 'caption': None, 'phone': None, 'name': None, 'saved': False}
    
    # clica no contato
    if click_on_contact():
        time.sleep(1)
    else:
        return 'Nao conseguiu clicar no contato'
    
    # CHAMA TODAS AS FUNCOES E MONTA UM DICIONARIO COM TODAS AS INFORMACOES
    getImage()
    time.sleep(0.3)
    getCaption()
    time.sleep(0.3)
    get_Name()
    time.sleep(0.3)
    getPhone()
    time.sleep(0.3)
    
    #fecha informacoes do contato
    esc_conversation()

    return contact_info

# %%
# FUNCOES QUE LIDAM COM O SCROLL UP DAS CONVERSAS PARA CAPUTRAR TODO O HISTORICO
def block_time(mensagem):
    days_week = ['TODAY', 'YESTERDAY', 'MONDAY', 'TUESDAY', 'WEDNESDAY', 'THURSDAY', 'FRIDAY', 'SATURDAY', 'SUNDAY', 
                'HOJE', 'ONTEM', 'SEGUNDA-FEIRA', 'TERÇA-FEIRA', 'QUARTA-FEIRA', 'QUINTA-FEIRA', 'SEXTA-FEIRA', 'SÁBADO', 'DOMINGO']
    try:
        content = mensagem.text
        if len(content) == 10 and content[2] == '/' and content[5] == '/':
            return content
        elif content in days_week:
            #chama funcao que vai tratar o dia da semana e devolver uma data
            content = correct_day(content)
            return content
        else:
            return False
    except Exception as error:
        return False
    
#CORRIGE O DIA DA SEMANA CASO NAO SEJA UMA DATA ESPECIFICA
def correct_day(day_name):
    #traduz o dia da semana caso o whatsapp esteja em portugues
    d = date.today()
    
    days_pt = {'SEGUNDA-FEIRA': 'monday', 'TERÇA-FEIRA': 'tuesday', 'QUARTA-FEIRA': 'wednesday', 'QUINTA-FEIRA': 'thursday', 'SEXTA-FEIRA': 'friday', 'SÁBADO': 'saturday', 'DOMINGO': 'sunday', 'HOJE': 'TODAY', 'ONTEM': 'YESTERDAY'}
    if day_name in days_pt.keys():
        day_name = days_pt[day_name]
    
    if day_name == 'TODAY':
        corrected = date.today()
        return corrected.strftime('%d/%m/%Y')
    elif day_name == 'YESTERDAY':
        corrected = d + timedelta(days=-1)
        return corrected.strftime('%d/%m/%Y')
    
    days_of_week = ['sunday','monday','tuesday','wednesday','thursday','friday','saturday']
    target_day = days_of_week.index(day_name.lower())
    delta_day = target_day - d.isoweekday()
    
    if delta_day >= 0: delta_day -= 7 # go back 7 days
    corrected = d + timedelta(days=delta_day)
    return corrected.strftime('%d/%m/%Y')

# VERIFICA SE EH O FIM DA CONVERSA
def verify_end():
    engine_messages = ['As mensagens e chamadas dessa conversa estão protegidas com criptografia de ponta a ponta.']
    try:
        for element in driver.find_elements_by_xpath('//div[@role="button"]'):
            if element.text in engine_messages:    
                return True
        return False
    except:
        return False

def scroll_history():
    #se nao for o fim da conversa, ira dar scroll para cima
    run = True
    while run: 
        if not verify_end():
            try:
                div_chat = driver.find_element_by_class_name('_1ays2')
                driver.execute_script("arguments[0].scrollIntoView(true);", div_chat)
                time.sleep(0.3)
            except:
                return False
        else:
            run = False
    return True

# %%
# FUNCOES PARA TRATAR CADA MENSAGEM, TIME, STATUS, SE FOI ENVIADA OU RECEBIDA E CONTEUDO
def get_time(mensagem):
    #verifica o horario da mensagem
    #pega o tempo de cada mensagem
    try:
        time = mensagem.find_element_by_css_selector('span._3fnHB').text
        return time
    except:
        return 'ENGINE'
        pass

def get_source_status(mensagem, time):
    #verifica se eh mensagem recebida ou enviada
    #se for enviada verifica o status
    try:
        status = mensagem.find_element_by_css_selector('path').get_attribute('fill') 
        if status == 'FFF':
            return 'sent'
        elif status == '92A58C':
            return 'delivered'
        else:
            return 'viewed'
    except:
        #se nao tiver icone de status e nao for o balao de data do whatsapp, eh mensagem recebida
        if time != 'ENGINE':
            return 'received'
        else:
            #criar metodo que ira organizar as mensagens em um bloco de tempo
            return 'ENGINE'

def verify_content(mensagem):
    #verifica qual o conteudo da mensagem
    content = {'content': '', 'type': ''}
    
    #verifica se eh um audio
    try:
        audio = mensagem.find_element_by_css_selector('audio').get_attribute('src')
        content['content'] = 'audio: ' + str(audio)
        content['type'] = 'audio'
    except:
        #verifica se eh umagem
        try:
            link = mensagem.find_element_by_css_selector('img').get_attribute('src')
            content['content'] = link
            content['type'] = 'image'
        except:
            try:
                video = mensagem.find_element_by_class_name('_3_IKd')
                content['content'] = 'duracao do video: ' + str(video.text)
                content['type'] = 'video'
            except:
                #se nao for imagem nem video nem audio eh texto, se for documento pegara o nome do arquivo
                try:
                    content_msg = mensagem.text.split('\n')
                    
                    if '#NaBike' in content_msg:
                        content['content'] = '|'.join(content_msg)
                        content['type'] = 'automatic'
                    elif len(content_msg) > 2 and content[0].startswith('+55') and content[2].startswith('+55') :
                        content['content'] = '|'.join(content_msg)
                        content['type'] = 'replie'
                    else:
                        #verifica se eh mensagem deletada
                        try:
                            mensagem.find_element_by_class_name('-bh0C')
                            content['content'] = 'This message was deleted'
                            content['type'] = 'deleted'
                        except:
                            #se nao for nenhuma das possibilidaes anteriores, eh texto
                            lengh = mensagem.text.split('\n')
                            if len(lengh) > 1:
                                content['content'] = str(mensagem.text)
                                content['type'] = 'text'
                            else:
                                content['content'] = lengh[0]
                                content['type'] = 'text'
                except:
                    try:
                        lengh = mensagem.text.split('\n')
                        if len(lengh) > 1:
                            content['content'] = str(mensagem.text)
                            content['type'] = 'text'
                        else:
                            content['content'] = lengh[0]
                            content['type'] = 'text'
                    except Exception as error:
                        print(error)
                        content['content'] = 'desconhecido'
                        content['type'] = 'unknown'  
    return content

# %%
# PEGA O CONTEUDO DAS MENSAGENS E DO CONTATO
def getContent():
    div_chat = driver.find_element_by_class_name('_1ays2')
    mensagens = div_chat.find_elements_by_class_name('FTBzM')

    
    history = {}
    
    #pega informacoes do contato
    contanct_data = getContactData() 
    
    timeline = []
    date = 'no date'
    
    for msg in mensagens:
        message = {'status': None, 'time': None, 'content': None, 'type': None}
        
        #pega o tempo de cada mensagem
        message['time'] = get_time(msg)
        
        #verifica se eh mensagem enviada ou recebida, se a mensagem nao tiver tempo eh o balao com a data
        message['status'] = get_source_status(msg, message['time'])
        
        content = verify_content(msg)
        
        message['type'] = content['type']
        message['content'] = content['content']
        
        is_time = block_time(msg)
        if is_time != False:
            #se for tempo, cria um dicionario que armazena o a lista de dicionarios com dados de cada mensagem
            date = is_time
            timeline.append({date: []})
        else:
            #adiciona o dicionario de dados na lista que ja existe
            try:
                timeline[-1][date].append(message)
            except IndexError:
                timeline.append({date: []})
                timeline[-1][date].append(message)
        
    data = {'contact': contanct_data, 'history': timeline}
    return data

# %%
# SALVA AS INFORMACOES COLETADAS NO BANCO DE DADOS
def save_to_db(data):
    #RECEBE O DICIONARIO GERADO COM AS DUAS CHAVES PRINCIPAIS E SALVA NO BANCO DA DADOS
    
    database = saveData.Database()
    #salva as informacoes de contato no banco
    database.save_contact_info(data['contact'])

    #salva o historico de conversas no banco
    for date in data['history']:
        #o historico esta salvo como uma lista de dicionarios onde cada dicionario possui uma data como chave e uma lista de dicionarios com dados da mensagem
        date_key = [key for key in date.keys()][0] #extrai a chave data
        print('saving history from day {}...'.format(date_key))
        database.save_history(date[date_key], date_key, carlos_296['contact']['phone'], carlos_296['contact']['name'])
    
    print('Saved!')

# %%
# SALVA LOCALMENTE AS INFORMACOES COLETADAS
def contact_info_txt(contact_info):
    try:
        if 'history' not in os.listdir():
            os.mkdir('history')

        contact_name = 'history/' + str(''.join(filter(str.isdigit, contact_info['phone']))) + '_contact.txt'

        with open(contact_name, 'a') as filee:
            for key in contact_info.keys():
                line = str(key) + ': ' + str(data_contact['contact'][key]) + '\n'
                filee.writelines(line)


        return 'contact info saved as: ' + str(contact_name)
    except Exception as error:
        print(type(error))
        print(error)
    
def history_csv(history, contact_name):
    # CRIA UM DATAFRAME COM O HISTORICO DE CONVERSAS
    try:
        df = pd.DataFrame(columns=['date', 'status', 'content', 'time', 'type'])

        for date in history:
            #o historico esta salvo como uma lista de dicionarios onde cada dicionario possui uma data como chave e uma lista de dicionarios com dados da mensagem
            date_key = [key for key in date.keys()][0] #extrai a chave data
            for msg in date[date_key]:
                df = df.append({'date': date_key, 'status': msg['status'], 'content': msg['content'], 'time': msg['time'], 'type': msg['type']}, ignore_index=True)

        # EXPORTA EM CSV
        if 'history' not in os.listdir():
            os.mkdir('history')

        history_name = 'history/' + str(''.join(filter(str.isdigit, contact_name))) + '_history.csv'
        df.to_csv(history_name, encoding='utf-8')

        return 'history info saved as: ' + str(history_name)
    except Exception as error:
        print(type(error))
        print(error)

# %%
def total_conversations():
    try:
        chat_list = driver.find_elements_by_class_name('X7YrQ')
        
        total = 0
        for chat in chat_list:
            starter = chat.get_attribute('style').find(':')
            delimiter = chat.get_attribute('style').find(';')
            found = int(''.join(filter(str.isdigit, chat.get_attribute('style')[starter:delimiter])))
            if found > total:
                total = found
        return total
    except:
        return 'Total Not Found'

# %%
# #eh preciso o argumento force=True para iniciar a navegacao pelas conversas
# # down_chat(force=True)
# count = 178
# chats = total_conversations()
# for i in range(chats):
#     count += 1
#     time.sleep(1)
#     if scroll_history():
#         data_contact = getContent()
        
#         #save_to_db(data_contact)
#         print(contact_info_txt(data_contact['contact']))
#         print(history_csv(data_contact['history'], data_contact['contact']['phone']))
    
#     print('\n{} de {} historicos salvos'.format(count, chats))
#     down_chat(force=False)
#     if count == chats - 10:
#         choice = input('continuar? aperte 1 se deseja parar')
#         if choice == '1':
#             break

# %%
# VERIFICA OS QUE JA ESTAO SALVOS NO DIRETORIO
path = './history/'
saved = []
for item in os.listdir(path):
    if item.endswith('.txt'):
        with open(path + item, 'r') as filee:
            data = filee.readlines()
            for line in data:
                if ('name') in line:
                    saved.append(line[line.find(':')+2:line.find('\n')])

# %%
# down_chat(force=True)
# for i in range(450):
#     down_chat()
#     time.sleep(0.3)
input('aperte enter se o whatsapp ja estiver aberto')

# %%
#eh preciso o argumento force=True para iniciar a navegacao pelas conversas
# down_chat(force=True)
i = len(saved)
chats = total_conversations()
for i in range(chats):
    try:
        time.sleep(0.5)
        name = driver.find_element_by_xpath("//div[@class='_19vo_']").text
        if name not in saved:
            if scroll_history():
                try:
                    data_contact = getContent()

                    #save_to_db(data_contact)
                    print(contact_info_txt(data_contact['contact']))
                    print(history_csv(data_contact['history'], data_contact['contact']['phone']))
                except:
                    print('ao salvar conversa')
                    break
                print('\n{} de {} historicos salvos'.format(i, chats))
            down_chat()
        else:
            time.sleep(0.5)
            down_chat()
    except Exception as error:
        print('quebrou no loop principal')
        break
        print(type(error))
        print(error)
        pass
    break
# Out:
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=78.0.3904.108)
#
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ea0992bb-6a2d-4204-adde-7da3e1853804/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bc122e8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/380f3649-7c44-4b74-a8ce-8cc0458175ca/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be0ee10>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/5f5a63d8-4bb2-4a09-8cbf-a394b254c98d/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bde9d68>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/2652fabd-64ba-4e86-9851-46a6091fee68/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be1ce10>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/b2fd52f1-0023-4e50-8c0e-cc16d2ad6cf9/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd44438>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/d5337870-32be-4353-a730-405197212b45/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bdaef98>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/26f6e137-0fd2-4055-8f44-cca8a9d01700/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be18710>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/3509a565-fc93-4cbe-8fc0-68220e9ef298/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bcf1b00>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/76cdcd9b-8e33-4778-b424-3952047be08c/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296c0b42e8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ed04018b-8263-4689-b8e6-658f270060c8/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f2998f47be0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/8367ce9e-b9f1-4c1a-bc20-041616010b89/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd3fc88>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/6a60b697-e33a-4345-b93b-06312d89be16/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bde9a20>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/7e225986-25f4-4f6f-86b9-7d99dd78f715/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be0e320>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/1a83e707-a02a-4a3a-b35a-3ba930e684b8/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb43400>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/22957b7c-e293-47c4-a59e-09d882b71a43/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd5f3c8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/a4d9633d-a639-4044-8a55-225322d41e82/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bdadc18>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/8988c177-7bea-4d70-b9d8-5721f84e0b4b/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bba7a20>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/bcb99364-8fb9-4a15-9494-b8f8e5a7f26f/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be1c080>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/0efb4479-b88a-4d92-8228-5fb1de1f8d4e/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd44198>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/90be1984-baa2-49fb-85f0-aff5bf893f49/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bdb4630>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/e0db3abf-bb99-4764-8017-c92d28600064/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb56a58>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/32816438-81ba-47d1-b4e8-233c2acac544/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296c0b4048>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/e3ad9f19-be92-4695-a2b5-c0797228107c/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd3fdd8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ef189dd8-1714-4361-a6f1-f148eab903fa/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bc05320>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/137ac784-1e33-407f-8fb2-6bc2491efead/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be0e048>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/f121b33a-4202-49cc-87ca-1f588d393f99/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb43a58>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/bb2c0530-571c-446f-86d3-55bacac83b48/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be0e5f8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/878c1f2d-3a47-4b60-8a84-cdbe023212a3/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb43048>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/44de6ffc-9ab1-46ad-9cf6-e6ecef40649d/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb56dd8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ae801ea2-05cb-4975-aa5e-0e000539b6d5/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb56c18>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/7157710f-ddad-46d9-91fd-36e989004606/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296c4b4668>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/7f3dda74-8c5c-4ff4-a29d-36e024c1a1b7/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f29a31ae5f8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/d7cfdece-bf88-471b-8b6d-6708515472ad/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be18668>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/c2a3fa85-e8dc-4924-bac9-3108e4cc8ae8/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd44b70>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/7b858de6-877b-4492-9b36-1331e39c6187/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd44da0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/2404e0f1-4f6a-4e3d-ba8a-344a684a9609/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd3fc88>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/80116570-3740-4060-99bb-22c5be40eb8c/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bde96d8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/37b45b58-2d62-49b1-bf0e-b4490207047b/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bdad898>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/f9a03cdf-4ee7-4f31-bb38-e7fc96071744/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bba7320>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/260e134f-a89c-4dfe-b638-384dd1d5e6ee/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf4048>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/b18d4746-7b35-4af0-a442-e32f594845c0/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb03ef0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/0a8a1415-48f2-4a9b-98c2-7b46d2647728/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb030f0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/1b11dce2-4d26-404d-9a24-4af16d312bf0/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb43b70>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/416e9713-b3fd-4ce7-bb13-3d3e4ef7ac79/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb435f8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/0673cc71-f056-4d42-a0c5-fd13c7319e89/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bba7ac8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/b6b5801f-1f8a-4a57-bf14-b266e17d9620/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be1cac8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/4fb7e7dd-73bd-44d4-be35-30cd483b9c46/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bde9240>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/5e2833d8-36cd-4d17-9f85-559ed1b4fed2/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baa9a20>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/de115433-91d4-4f9c-a79e-f4dccf9a77de/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bde9c18>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/d41a7f8e-e431-4558-b131-4b9e2d61707e/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bdad7b8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/2f7428e3-7253-4ad2-aa58-ef770fffcb75/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb435f8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/52f7326d-db54-43d3-8ae8-5f8420f8faaf/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf4e80>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/1145f158-8771-4233-b53a-1b80fa394d0a/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb14cf8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/6a88758b-9d87-411b-9be8-a7fe0048e569/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bacd4a8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/bc988f44-fee7-4d2f-bccd-abbe7ed3f154/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296babcd68>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/cdcb3fa7-4cae-4353-a6d3-ac5f31f383c8/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb03c18>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/c29caf0f-8fb7-4e2c-bae8-571d3b5070f5/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296babccc0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/960b9d34-da78-4e77-868a-5f4d18cbc5b4/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf4400>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/e24159b9-b4aa-43c0-9e79-a0b9b467c6f9/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb56f98>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/be373293-cac0-47bc-9870-23dd8652d622/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bdadbe0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/e6346957-fa2e-4934-8f4a-5225d25f2aad/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be1cd68>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/e62adc9d-2e27-4854-bd6a-d7405599d024/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bc12d30>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/c268eef8-2ef4-4c78-ab17-942b12bb00b4/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bba7470>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/9e76798f-a53a-470e-8545-ecefb319e550/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb4a5f8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/177a510c-2557-4605-9a36-0b4406bac7dd/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb03c18>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/0fa21837-3e14-447e-a264-d596b66c64b8/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296babce10>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/a84f14f8-4c0b-41e3-bd5e-be519180917e/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296babc438>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/b987c9de-113d-4caa-b482-060af66d6fe1/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296babc240>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/becb1886-8ba8-456d-a12d-4eba632c1db6/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb03780>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/198c3c20-4900-4b8f-8838-ef8f56b5a56d/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf4128>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/6d4e4cac-91a3-40e0-99fe-2f392815e975/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd5f438>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/8157c1a5-e031-4945-b4c7-46b337eadfaf/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be0e630>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/97568480-319e-4cdb-8665-f0977ef20ba7/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be185f8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/33bb8310-69de-4ad4-be76-3644b1f273c5/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be1ce80>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/2aef9ee8-fe7c-4a19-a088-413237b9a960/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bacd550>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/3eafe173-8909-4d1f-b94d-d742b5c3ffa4/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bba7940>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/8c89a026-b16b-4190-a477-6239cde395e5/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb43320>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/3a923761-550b-4e19-991d-6533b140e918/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf49e8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/5497846a-96cb-4586-87e6-577305ca31dd/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb43748>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/20a2d2fd-c2c5-4562-bf8b-ac7a56caf597/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb03828>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/77db5c56-f5cb-4b52-9d45-79528626a9a3/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba6b080>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/cb03457f-2f2c-4447-b116-14da5589cfc8/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba6bba8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/b4ee9e20-7449-4697-af8c-a58c26e2f9d0/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb4ae80>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ef2badc9-c440-405a-a00b-5fc9210baf5b/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd44da0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ba69ddd8-19b8-433c-8ae5-cb3f070fc737/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd44e80>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/3acca7fb-b5e9-4abe-bbc9-0b4a69e3d384/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bde9860>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/72f1b150-a798-4d4e-a793-89e26df4bc4c/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bacdc50>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/574fd3c0-accb-44ad-88c8-335545339b7d/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba81860>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/7048afd8-a616-4cc5-ac9c-1881ccb28b3c/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f2998f47198>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/92b112fd-572b-4b2f-8abb-70255705c409/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb43a90>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/f32bb670-782d-468d-aae3-ffbe8cbc6e6f/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb14588>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/cb69b6ec-d2ab-438f-9464-1a930e35cf02/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296babc080>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/01f9ff3b-764a-4fdd-9c55-abcb05971d5f/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba6b710>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/0ed1d731-8aaa-449e-906a-6e83764e7ffb/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba2c6a0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/59c8158d-a027-4d3a-ac41-1a43d91b0467/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba96588>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/e1114d39-0837-492d-9b21-1aefd035cbd6/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba6b898>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/5d400247-34aa-4310-b840-251340b80491/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba96eb8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/4fe27f72-cda7-4af7-8318-fcbc828b38d9/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb03940>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/1c72837d-2c68-4d79-99cf-5418eca75301/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf4fd0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ee561a94-f64f-421c-aadb-48a6faffd503/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb437f0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/f3ddb79e-d64d-4dcf-a9e8-dd0d1c174045/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be1cf28>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/32b0289c-b90d-4b68-8ba3-d95a4197948b/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bde9048>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/811b33df-c1b6-4f8f-8034-e97cafe3d3da/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf4630>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/eadee9ee-a13e-496f-a4c7-5aee8d53d1cf/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb03e48>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/cb2063a3-7b8f-4ac5-ba84-47ef044a7170/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba6b128>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/3e404fd4-be45-4679-88b2-d6cbae6e50db/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba96f98>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/6331045f-66da-42ff-a16c-772fff638547/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba6b5f8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/31effaf4-8aff-4f4d-ba71-37b34c13ba28/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba96b00>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/47def4d0-40a2-41ef-835b-6c9ad20494b8/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba81a20>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/cfe96904-4d5d-44da-a0d6-fbdeb244389b/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296babcdd8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/507deff3-7c34-41c1-ba8a-124a735cc127/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb03ba8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/1e6f734d-060b-46df-8f2d-c7e18310dd78/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf4160>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/7c054471-d736-4c57-a7d2-30516062ebdd/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd5f240>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/a7761020-0b44-465e-9f7c-ad08caaf52bb/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be1ce48>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/19e8e38a-e183-433f-a8ec-e710430e7352/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb43390>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/d89f5da1-2497-4a03-9c34-2130a5be922a/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bd44ac8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/785c44d8-5376-4caa-a2a7-dd93f76ae1c4/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf4b38>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/e15a21b7-a729-4f95-abdd-d7bd5100aa47/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba81e10>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/2ee991f7-ac76-49da-8743-a21209ef8dcc/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba81978>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/a5d07cbc-f367-4736-8895-24750c444885/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bae3ba8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/a855eac2-89a2-4d36-86d6-23090b5e54fd/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba27128>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/d1044ef9-d39f-4615-bd62-e7e5a0bddbe9/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba27c50>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/651ab98b-6f39-42d7-92be-765642706709/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296babc198>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/6f18eb3e-80de-44b1-b858-f1362af73472/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be0e940>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/66f602ec-93bb-425c-b9f1-4c6cfeea2572/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be0ee80>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ddf3fb50-c115-4fd7-b18a-b67c543dee10/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb4af60>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/f55d5c53-62f1-4101-8842-9ae9703500a4/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba2c080>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ff143cdd-ecec-456f-b13a-3638a8bfdb1a/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba58908>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/589e89af-5325-4df9-956b-ca1c224c86f1/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296c4b4668>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/01a3569e-d3a5-4f03-ba52-db34b12ff773/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296baf4fd0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/da8dd8d5-6e47-4e74-b6de-61da2ef0005b/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296babc240>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/142934a3-aaf2-4618-a4b2-f395e97ffe3d/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba96358>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/b7550dd7-ec62-48ef-a28c-ed262a4a8e90/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba27278>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/440344e6-3a3d-462a-b3e6-ad69345fc961/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba00748>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/54acd64b-e125-4ce1-9b0a-4956926b3446/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296b9ea6d8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/065d5542-4f63-453b-8457-93c223eef372/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba274a8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/a619d385-3de6-4c8d-b8fc-617324092d75/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296b9ea160>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/7ea9c350-a77c-4c16-bfe5-d512e1d82152/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb14a20>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/21825872-8ede-44ba-8209-1a4b6a48ce7a/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296ba81c88>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/ccdfe7d8-3317-415c-a80d-490a3bb3c29f/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb56d30>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/76f32264-2ba0-4eac-b855-7253eb399ebf/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be1c780>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/8d86535f-916b-4033-aeb2-00ee8bb1d254/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb4a4a8>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/cf05028b-4d3c-48a8-9733-c9e29ed75bff/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296be0e9b0>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='127.0.0.1', port=40509): Max retries exceeded with url: /session/b4e4a67907e563e62046f300f7688839/element/6f96ba1e-05de-44c3-afed-62c622844b77/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f296bb14978>: Failed to establish a new connection: [Errno 111] Connection refused',))
# contact info saved as: history/554796976422_contact.txt
# ao salvar conversa
